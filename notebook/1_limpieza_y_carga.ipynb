# %%
import pandas as pd

# %%
import os

# %%
os.chdir('..')

# %%
# !ls
# Out:
# data  notebook	requierements.txt

# %%
df_gastos_varios = pd.read_excel('./data/12_DICIEMBRE_2020.xlsx', sheet_name='GASTOS VARIOS', skiprows=5)
df_gastos_varios['SHEET'] = 'GASTOS VARIOS'

# %%
df_contratistas = pd.read_excel('./data/12_DICIEMBRE_2020.xlsx', sheet_name='CONTRATISTAS Y FDO FED', skiprows=5)
df_contratistas['SHEET'] = 'CONTRATISTAS Y FDO FED'

# %%
df_servicios = pd.read_excel('./data/12_DICIEMBRE_2020.xlsx', sheet_name='SERV PPROF', skiprows=5)
df_servicios['SHEET'] = 'SERV PPROF'

# %%
df_comunicion = pd.read_excel('./data/12_DICIEMBRE_2020.xlsx', sheet_name='COMUNICACION', skiprows=5)
df_comunicion['SHEET'] = 'COMUNICACION'

# %%
df_personales = pd.read_excel('./data/12_DICIEMBRE_2020.xlsx', sheet_name='SERV. PERS.', skiprows=5)
df_personales['SHEET'] = 'SERV. PERS.'

# %%
df_compras_dic = pd.concat([df_gastos_varios, df_contratistas, df_servicios, df_comunicion, df_personales])
df_compras_dic.head(14)
# Out:
#          NUM BEN                                    BENEFICIARIO  \
# 0         110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.
# 1         110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.
# 2         110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.
# 3         110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.
# 4         110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.
# 5         110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.
# 6         110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.
# 7         110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.
# 8         110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.
# 9         110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.
# 10        110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.
# 11        110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.
# 12        110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.
# ...

# %%
df_compras_dic_com = df_compras_dic.dropna(how='any')

# %%
len(df_compras_dic_com)
# Out:
# 1540

# %%
df_compras_dic.dtypes
# Out:
# NUM BEN                 object
# BENEFICIARIO            object
# RFC                     object
# FACTURA                 object
# CONTRATO                object
# CONCEPTO                object
# TIPO                    object
# # OP                   float64
# FECHA           datetime64[ns]
# IMPORTE                float64
# SHEET                   object
# dtype: object

# %%
df_compras_dic_com['FECHA'].apply(lambda x: x.month).value_counts()
# Out:
# FECHA
# 12    1540
# Name: count, dtype: int64

# %%
df_compras_dic_com.head()
# Out:
#   NUM BEN                                    BENEFICIARIO           RFC  \
# 0  110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 1  110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 2  110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 3  110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 4  110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
#
#                   FACTURA      CONTRATO  \
# 0  LLS AF8458-158008-3972  OT. 20204373
# 1  LLS PF6916-158008-4041  OT. 20204425
# 2  LLS PF6917-158008-3975  OT. 20204376
# 3  LLS PF7004-158008-3971  OT. 20204374
# 4  LLS PF7137-158008-4554  OT. 20205130
#
#                                             CONCEPTO TIPO         # OP  \
# 0  REEMPLAZO E INSTALACION DE AMORTIGUADORES (DEL...   TR    1019110.0
# 1  REEMPLAZO E INSTALACION DE OCHO BIRLOS Y NUEVE...   TR    1019110.0
# ...

# %%
# !ls
# Out:
# data  notebook	requierements.txt

# %%
df_compras_dic_com.to_csv('notebook/data/clean_compras.csv', index=None)
